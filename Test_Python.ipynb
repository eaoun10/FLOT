# %%
#addition
10+2
#subtraction
10-2
#multiplication
10*2
#division
10/2
#exponents
10**2
print('Hello World!')
a=2
b=6
c=a*b
print(c)
# Out:
# Hello World!
# 12

# %%
temp=10+20 #k
temp2=10/3

# %%
print(round(temp2,2))
# Out:
# 3.33

# %%
dH1=-1299.5 #kj
dH2=-393.5
dH3=-285.8

dH_acetylene = -dH1+2*dH2+dH3

print('ΔH° for the production of acetylene:', dH_acetylene, 'kJ')
# Out:
# ΔH° for the production of acetylene: 226.7 kJ

# %%
dH1=322 #kJ
dH2=289
dH3=572

dH_iron = dH1+(3/2)*dH2+dH3

print('ΔH° for the production of iron:', dH_iron, 'kJ')
# Out:
# ΔH° for the production of iron: 1327.5 kJ

# %%
# !pip install matplotlib-venn
import matplot.lib.pyplot as plt
x=[1,2,3,4]
y=[200,400,600,800]
plt.plt(x,y)
plt.xlabel('x-axis(y units)')
plt.label('y-axis(x units)')
plt.title('My first graph')
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4]
y=[200,400,600,800]
plt.plot(x,y)
plt.xlabel('x-axis(y units)')
plt.ylabel('y-axis(x units)')
plt.title('My first graph')
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4]
y=[200,400,600,800]
plt.figure(figsize=(7,7))
plt.xlim(0,1)
plt.ylim(100,1600)
plt.plot(x,y,'-ok', color='green')
plt.xlabel('x-axis(y units)')
plt.ylabel('y-axis(x units)')
plt.title('My second graph!', fontsize=2)
plt.show()
# Out:
# <ipython-input-40-330e9c182adc>:7: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(x,y,'-ok', color='green')

# %%
import numpy as np
import matplotlib.pyplot as plt
x = [1,2,3,4, 6]
y = [200,400,600,800, 1000]
plt.plot(x, y, 'o', color='green')
coef = np.polyfit(x,y,deg=1)
poly1d_fn = np.poly1d(coef)
slope, intercept = np.polyfit(x, y, deg=1)
print('y =', (round(slope,2)),'x +', (round(intercept,2)))
plt.plot(x, poly1d_fn(x))
plt.xlabel('x - axis (y units)')
plt.ylabel('y - axis (x units)')
plt.title('Linear Fit!', fontsize=12)

plt.show()
# Out:
# y = 162.16 x + 81.08

# %%
R=0.08206#L atm mol¯1 K¯1
def compute_gas_V(gas_P,gas_T,gas_mol):
  return(gas_mol*R*gas_T)/gas_P
print(compute_gas_V(1.01,298.15,0.00831),'L')
# Out:
# 0.20130102038613856 L

# %%
R = 0.08206 #L atm mol¯1 K¯
n = 1.0 #mole
T = 298.15 #K
P=np.arange(60,200,10)
plt.plot(1/(compute_gas_V(P,T,n)),P,color='blue', label=str(T)+'K')
plt.xlabel('P(atm)')
plt.ylabel('1/V (L)')
plt.title('Bowles Law')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
